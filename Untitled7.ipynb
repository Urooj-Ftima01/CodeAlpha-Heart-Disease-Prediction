# %%
# ====== 1. Imports ======
# !pip install --quiet scikit-learn seaborn matplotlib pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (accuracy_score, classification_report,
                             confusion_matrix, roc_auc_score, roc_curve)

# ====== 2. Load UCI Heart (Cleveland) dataset ======
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"
cols = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach',
        'exang','oldpeak','slope','ca','thal','target']
df = pd.read_csv(url, names=cols)

print("Raw shape:", df.shape)
display(df.head())

# ====== 3. Clean & preprocess ======
# Replace '?' with NaN, convert numeric columns
df.replace('?', np.nan, inplace=True)
# Convert appropriate columns to numeric
for c in ['ca','thal']:
    df[c] = pd.to_numeric(df[c], errors='coerce')

# Target: 0 = no disease, >0 = disease. Convert to binary
df['target'] = df['target'].apply(lambda x: 1 if x > 0 else 0)

print("\nAfter cleaning, null counts:")
print(df.isnull().sum())

# Option: drop rows with missing values (small dataset) OR impute
df = df.dropna().reset_index(drop=True)
print("After dropna shape:", df.shape)

# ====== 4. Quick EDA ======
plt.figure(figsize=(6,4))
sns.countplot(x='target', data=df)
plt.title('Class distribution (0=no disease, 1=disease)')
plt.show()

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation matrix')
plt.show()

# ====== 5. Prepare X, y and split (stratified) ======
X = df.drop('target', axis=1)
y = df['target']

# If any categorical features (cp, restecg, slope, thal, ca, sex, fbs, exang),
# we can one-hot encode cp, restecg, slope, thal if desired. RandomForest handles ordinal as well.
X_encoded = pd.get_dummies(X, columns=['cp','restecg','slope','thal'], drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42, stratify=y)

print("Train shape:", X_train.shape, "Test shape:", X_test.shape)

# ====== 6. Train a baseline RandomForest ======
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
y_proba = rf.predict_proba(X_test)[:,1]

print("\nRandomForest Results")
print("Accuracy:", accuracy_score(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_proba))
print("\nClassification Report:\n", classification_report(y_test, y_pred, zero_division=0))

# Confusion matrix
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted"); plt.ylabel("Actual"); plt.title("Confusion Matrix")
plt.show()

# ====== 7. Optional: Try Logistic Regression for comparison ======
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
y_proba_lr = lr.predict_proba(X_test)[:,1]
print("\nLogistic Regression Results")
print("Accuracy:", accuracy_score(y_test, y_pred_lr))
print("ROC AUC:", roc_auc_score(y_test, y_proba_lr))

# ====== 8. Save cleaned dataset & model if wanted ======
df.to_csv('heart_disease_cleaned.csv', index=False)
print("\nSaved cleaned dataset as 'heart_disease_cleaned.csv' in Colab workspace.")

# To download the CSV to your PC (run this cell in Colab)
from google.colab import files
files.download('heart_disease_cleaned.csv')
# Out:
# Raw shape: (303, 14)
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  target
# 0    3.0  0.0  6.0       0
# 1    2.0  3.0  3.0       2
# 2    2.0  2.0  7.0       1
# 3    3.0  0.0  3.0       0
# 4    1.0  0.0  3.0       0
# After cleaning, null counts:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# target      0
# dtype: int64
# After dropna shape: (297, 14)
# ...
